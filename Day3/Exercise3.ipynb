# %% [markdown]
# ## 3. Current DateTime Display
#
# Write a Python program to display the current date and time.
# Sample Output :
# Current date and time :
# 2014-07-05 14:34:14

# %%
import datetime
now = datetime.datetime.now()

# %%
print(f"The current date and time is:",now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# The current date and time is: 2025-02-15 16:24:36.682944

# %% [markdown]
# ### Explanation
# The code import the "datetime" module to get the current date and time.
